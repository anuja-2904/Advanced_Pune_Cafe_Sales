# %%
import pandas as pd

# %%
df = pd.read_csv("Downloads/Advanced_Pune_Cafe_Sales_2000.csv")

# %%
df.head()
# Out:
#    order_id        date outlet_location  outlet_manager customer_type  \
# 0  ORD51036  2025-10-19       Hinjewadi      Priya Nair       Regular
# 1  ORD94971  2025-10-09         Kothrud     Arjun Mehta       Tourist
# 2  ORD82709  2025-10-07     Viman Nagar  Rohit Deshmukh       Tourist
# 3  ORD61541  2025-10-22     Viman Nagar  Rohit Deshmukh       Tourist
# 4  ORD20674  2025-10-07         Kothrud     Arjun Mehta           New
#
#   item_category            item_name  quantity_sold  price_per_unit  \
# 0         Snack  Cheese Garlic Bread              4             245
# 1      Beverage           Cappuccino              3             134
# 2      Beverage            Green Tea              3             243
# 3      Beverage           Cappuccino              1             174
# 4       Dessert           Cheesecake              4             175
#
#    total_bill  ...  time_of_day  temperature_c day_of_week customer_rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 2000 non-null   object
#  1   date                     2000 non-null   object
#  2   outlet_location          2000 non-null   object
#  3   outlet_manager           2000 non-null   object
#  4   customer_type            2000 non-null   object
#  5   item_category            2000 non-null   object
#  6   item_name                2000 non-null   object
#  7   quantity_sold            2000 non-null   int64
#  8   price_per_unit           2000 non-null   int64
#  9   total_bill               2000 non-null   int64
#  10  cost_price               2000 non-null   float64
#  11  profit                   2000 non-null   float64
#  12  payment_mode             2000 non-null   object
#  13  time_of_day              2000 non-null   object
# ...

# %%
df.describe()
# Out:
#        quantity_sold  price_per_unit   total_bill   cost_price       profit  \
# count    2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean        2.499500      200.353000   500.813500   350.866920   149.946580
# std         1.113831       58.527866   274.319218   195.203022    88.624357
# min         1.000000      100.000000   100.000000    63.150000    21.620000
# 25%         2.000000      150.000000   267.750000   183.082500    79.637500
# 50%         3.000000      201.000000   460.000000   316.375000   131.355000
# 75%         3.000000      249.000000   696.750000   478.690000   203.172500
# max         4.000000      300.000000  1200.000000   946.730000   477.600000
#
#        temperature_c  customer_rating  discount_percent  final_amount  \
# count    2000.000000      2000.000000       2000.000000   2000.000000
# mean       29.518550         3.993100          7.642500    462.413100
# std         3.165595         0.581938          5.519957    255.380474
# ...

# %%
df.describe(include = "all")
# Out:
#         order_id        date outlet_location outlet_manager customer_type  \
# count       2000        2000            2000           2000          2000
# unique      1979          31               5              5             3
# top     ORD63406  2025-10-19   Koregaon Park    Amit Sharma       Tourist
# freq           2          65             428            428           675
# mean         NaN         NaN             NaN            NaN           NaN
# std          NaN         NaN             NaN            NaN           NaN
# min          NaN         NaN             NaN            NaN           NaN
# 25%          NaN         NaN             NaN            NaN           NaN
# 50%          NaN         NaN             NaN            NaN           NaN
# 75%          NaN         NaN             NaN            NaN           NaN
# max          NaN         NaN             NaN            NaN           NaN
#
#        item_category  item_name  quantity_sold  price_per_unit   total_bill  \
# ...

# %% [markdown]
# 1. **order_id**
# - As the count in order_id feature is 2000 it has no missing values
# - In this feature there are 1979 unique values
# - ORD63406 is the most frequent order_id which has been repeated 2 times
#
# 2. **date**
# - As the count in date feature is 2000 it has no missing values
# - In this feature there are 31 unique values
# - 2025-10-19 is the most frequent date which has been repeated 65 times
#
# 3. **outlet_location**
# - As the count in outlet_location feature is 2000 it has no missing values
# - In this feature there are 5 unique values
# - Koregaon Park is the most frequent outlet_location which has been repeated 428 times
#
# 4. **outlet_manager**
# - As the count in outlet_manager feature is 2000 it has no missing values
# - In this feature there are 5 unique values
# - Amit Sharma is the most frequent outlet_manager which has been repeated 428 times
#
# 5. **customer_type**
# - As the count in customer_type feature is 2000 it has no missing values
# - In this feature there are 3 unique values
# - Tourist is the most frequent customer_type which has been repeated 675 times
#
# 6. **item_category**
# - As the count in item_category feature is 2000 it has no missing values
# - In this feature there are 3 unique values
# - Beverage is the most frequent item_category which has been repeated 696 times
#
# 7. **item_name**
# - As the count in item_name feature is 2000 it has no missing values
# - In this feature there are 17 unique values
# - Ice Cream is the most frequent item_name which has been repeated 145 times
#
# 8. **quantity_sold**
# - As the count in quantity_sold feature is 2000 it has no missing values
# - The mean average is 2.49 and the standard deviation is 1.11
# - In this feature 1.0 is the minimum value and 4.0 is the maximum value
# - In this feature 25% of quantity sold lies below 2.0
# - In this feature 50% of quantity sold lies below 3.0
# - In this feature 75% of quantity sold lies below 3.0
#
# 9. **price_per_unit**
# - As the count in price_per_unit feature is 2000 it has no missing values
# - The mean average is 200.35 and the standard deviation is 58.52
# - In this feature 100 is the minimum value and 300 is the maximum value
# - In this feature 25% of price_per_unit lies below 150
# - In this feature 50% of price_per_unit lies below 201
# - In this feature 75% of price_per_unit lies below 249
#
# 10. **total_bill**
# - As the count in total_bill feature is 2000 it has no missing values
# - The mean average is 500.81 and the standard deviation is 274.31
# - In this feature 100 is the minimum value and 1200 is the maximum value
# - In this feature 25% of total_bill lies below 267.75
# - In this feature 50% of total_bill lies below 460
# - In this feature 75% of total_bill lies below 696.75
#
# 11. **cost_price**
# - As the count in cost_price feature is 2000 it has no missing values
# - The mean average is 350.86 and the standard deviation is 946.73
# - In this feature 63.15 is the minimum value and 1200 is the maximum value
# - In this feature 25% of cost_price lies below 183.08
# - In this feature 50% of cost_price lies below 316.37
# - In this feature 75% of cost_price lies below 478.69
#
# 12. **profit**
# - As the count in profit feature is 2000 it has no missing values
# - The mean average is 149.94 and the standard deviation is 88.62
# - In this feature 21.62 is the minimum value and 477.60 is the maximum value
# - In this feature 25% of profit lies below 79.63
# - In this feature 50% of profit lies below 131.35
# - In this feature 75% of profit lies below 203.17
#
# 13. **payment_mode**
# - As the count in payment_mode feature is 2000 it has no missing values
# - In this feature there are 3 unique values
# - Card is the most frequent payment_mode which has been repeated 683 times
#
# 14. **time_of_day**
# - As the count in time_of_day feature is 2000 it has no missing values
# - In this feature there are 4 unique values
# - Morning is the most frequent time_of_day which has been repeated 524 times
#
# 15. **temperature_c**
# - As the count in temperature_c feature is 2000 it has no missing values
# - The mean average is 29.51 and the standard deviation is 3.16
# - In this feature 24 is the minimum value and 35 is the maximum value
# - In this feature 25% of temperature_c lies below 26.77
# - In this feature 50% of temperature_c lies below 29.60
# - In this feature 75% of temperature_c lies below 32.30
#
# 16. **day_of_week**
# - As the count in day_of_week feature is 2000 it has no missing values
# - In this feature there are 7 unique values
# - Wednesday is the most frequent day_of_week which has been repeated 324 times
#
# 17. **customer_rating**
# - As the count in customer_rating feature is 2000 it has no missing values
# - The mean average is 3.99 and the standard deviation is 0.58
# - In this feature 3 is the minimum value and 5 is the maximum value
# - In this feature 25% of customer_rating lies below 3.5
# - In this feature 50% of customer_rating lies below 4.0
# - In this feature 75% of customer_rating lies below 4.5
#
# 18. **discount_percent**
# - As the count in discount_percent feature is 2000 it has no missing values
# - The mean average is 7.64 and the standard deviation is 5.51
# - In this feature 0 is the minimum value and 15 is the maximum value
# - In this feature 25% of discount_percent lies below 5
# - In this feature 50% of discount_percent lies below 10
# - In this feature 75% of discount_percent lies below 15
#
# 19. **final_amount**
# - As the count in final_amount feature is 2000 it has no missing values
# - The mean average is 7.64 and the standard deviation is 5.51
# - In this feature 0 is the minimum value and 15 is the maximum value
# - In this feature 25% of final_amount lies below 5
# - In this feature 50% of final_amount lies below 10
# - In this feature 75% of final_amount lies below 15
#
# 20. **special_event**
# - As the count in special_event feature is 593 it has some missing values
# - In this feature there are 3 unique values
# - Weekend Special is the most frequent special_event which has been repeated 207 times
#
# 21. **staff_id**
# - As the count in staff_id feature is 593 it has some missing values
# - In this feature there are 30 unique values
# - ST22 is the most frequent staff_id which has been repeated 90 times
#
# 22. **day_type**
# - As the count in day_type feature is 2000 it has some missing values
# - In this feature there are 2 unique values
# - Weekday is the most frequent day_type which has been repeated 1483 times
#
# 23. **cumulative_sales_outlet**
# - As the count in cumulative_sales_outlet feature is 2000 it has no missing values
# - The mean average is 92518.35 and the standard deviation is 53543.12
# - In this feature 203.30 is the minimum value and 190768.20 is the maximum value
# - In this feature 25% of cumulative_sales_outlet lies below 46386.68
# - In this feature 50% of cumulative_sales_outlet lies below 91790.75
# - In this feature 75% of cumulative_sales_outlet lies below 138889.63

# %%
df.dtypes
# Out:
# order_id                    object
# date                        object
# outlet_location             object
# outlet_manager              object
# customer_type               object
# item_category               object
# item_name                   object
# quantity_sold                int64
# price_per_unit               int64
# total_bill                   int64
# cost_price                 float64
# profit                     float64
# payment_mode                object
# time_of_day                 object
# temperature_c              float64
# day_of_week                 object
# customer_rating            float64
# discount_percent             int64
# final_amount               float64
# special_event               object
# staff_id                    object
# day_type                    object
# cumulative_sales_outlet    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# order_id                      0
# date                          0
# outlet_location               0
# outlet_manager                0
# customer_type                 0
# item_category                 0
# item_name                     0
# quantity_sold                 0
# price_per_unit                0
# total_bill                    0
# cost_price                    0
# profit                        0
# payment_mode                  0
# time_of_day                   0
# temperature_c                 0
# day_of_week                   0
# customer_rating               0
# discount_percent              0
# final_amount                  0
# special_event              1407
# staff_id                      0
# day_type                      0
# cumulative_sales_outlet       0
# dtype: int64

# %%
df['special_event'] = df['special_event'].fillna(df['special_event'].mode()[0])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['date'] = pd.to_datetime(df["date"])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['quantity_sold'], color='skyblue', edgecolor='black')
plt.title('Quantity sold Distribution')
plt.xlabel('Quantity Sold')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Almost all bars are similar around 500
# - All are sold equally
# - **It is Uniform Distribution Quantity sold is similar**

# %%
plt.hist(df['price_per_unit'], color='skyblue', edgecolor='black')
plt.title('price_per_unit Distribution')
plt.xlabel('price_per_unit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Some have prices between 150 to 200
# - The median price is around 200
# - The lowest price is around 100
# - The highest price is around 300

# %%
plt.hist(df['total_bill'], color='skyblue', edgecolor='black')
plt.title('Total Bill Distribution')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Highest bill is between 200 to 400
# - As the total bill increases frequency are decreasing
# - Lowest total bill around 1200 is below 100
# - **It is Right Skewed Distribution Few bills have high amount**

# %%
plt.hist(df['cost_price'], color='skyblue', edgecolor='black')
plt.title('Cost Price Distribution')
plt.xlabel('Cost Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest cost price is around 200, it has frequency around 400
# - As the cost price is increasing frequncy is decreasing
# - The lowest cost price is above 800 which has frequency below 50
# - **It is Right skewed Distribution few cost prices are high**

# %%
plt.hist(df['profit'], color='skyblue', edgecolor='black')
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest profit is around 100, it has frequency above 400
# - As the profit is increasing, frequency starts decreasing
# - **It is Right skewed Distribution few profits are high**

# %%
plt.hist(df['temperature_c'], color='skyblue', edgecolor='black')
plt.title('Temperature_C Distribution')
plt.xlabel('Temperature_C')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Highest tempreature is around 30C
# - All have almost same frequency
# - 32C has the lowest tempreature

# %%
plt.hist(df['customer_rating'], color='skyblue', edgecolor='black')
plt.title('Customer Rating Distribution')
plt.xlabel('Customer Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Highest customer rating is around 5
# - Some customers gave almost similar ratings
# - Some customers gave low rating below 3.0

# %%
plt.hist(df['discount_percent'], color='skyblue', edgecolor='black')
plt.title('Discount Percent Distribution')
plt.xlabel('Discount Percent')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest discount percent is between 4 to 6
# - Discount percent around 10 and 14 have similar frequency
# - Discount percent 0 to 2 have low frequency

# %%
plt.hist(df['final_amount'], color='skyblue', edgecolor='black')
plt.title('Final Amount Distribution')
plt.xlabel('Final Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - Most amounts are between 200 to 400
# - As the final amount increases frequency starts decreasing
# - Frequency is very low for final amounts above 1000
# - **It is Right skewed Distribution some amounts are very high**

# %%
plt.hist(df['cumulative_sales_outlet'], color='skyblue', edgecolor='black')
plt.title('Cumulative Sales Outlet Distribution')
plt.xlabel('Cumulative Sales Outlet')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest cumulative sales outlet is between 50000 to 75000
# - All sales have almost similar frequency
# - The lowest cumulative sales is above 175000

# %%
plt.bar(df['date'],df['quantity_sold'], color ="skyblue")
plt.title("Quantity Sold by Date")
plt.xlabel('date')
plt.ylabel('quantity_sold')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# - All have same quantity of sales

# %%
plt.bar(df['outlet_location'],df['cumulative_sales_outlet'], color ="skyblue")
plt.title("Cumulative sales oulet by Outlet location")
plt.xlabel('outlet_location')
plt.ylabel('cumulative_sales_outlet')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Kothrud and baner have cumulative sales around 175000
# - Hinjewadi, Viman nagar and Koregaon Park have cumulative sales above 175000

# %%
plt.bar(df['date'],df['total_bill'], color ="skyblue")
plt.title("Total bill by Date")
plt.xlabel('date')
plt.ylabel('total_bill')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# - Almost similar bill around all dates
# - On few dates there is less bill amount

# %%
plt.bar(df['date'],df['profit'], color ="skyblue")
plt.title("Profit by Date")
plt.xlabel('date')
plt.ylabel('profit')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# - Highest profit is on 10-10-2025 around 500
# - Very low profit is on 3-10-2025 and 30-10-2025
# - Rest of all have almost similar profits

# %%
plt.scatter(df['total_bill'],df['profit'], color ="skyblue")
plt.title("profit by total_bill")
plt.xlabel('total_bill')
plt.ylabel('profit')
plt.show()

# %% [markdown]
# - **This is the positive correlation as the total bill increases profit also increases**

# %%
plt.scatter(df['price_per_unit'],df['quantity_sold'], color ="skyblue")
plt.title("quantity_sold by price_per_unit")
plt.xlabel('price_per_unit')
plt.ylabel('quantity_sold')
plt.show()

# %% [markdown]
# - **Pice per unit has no effect on quantity sold**
# - **Quantity sold is constant for all price units**

# %%
plt.scatter(df['discount_percent'],df['final_amount'], color ="skyblue")
plt.title("final_amount by discount_percent")
plt.xlabel('discount_percent')
plt.ylabel('final_amount')
plt.show()

# %% [markdown]
# - **As the discount percent increases the final amount is decreasing**
# - **Highest amount at 0 percent discount**

# %%
plt.plot(df['day_of_week'], df['profit'], color='blue')

plt.title('day_of_week by profit')
plt.xlabel('day_of_week')
plt.ylabel('profit')
plt.show()

# %%
plt.scatter(df['temperature_c'],df['quantity_sold'], color ="skyblue")
plt.title("quantity_sold by temperature_c")
plt.xlabel('temperature_c')
plt.ylabel('quantity_sold')
plt.show()

# %% [markdown]
# - **No effect of temperature on quantity sold**
# - **Quantity sold is similar along all temperature celsius**

# %%
plt.scatter(df['customer_rating'],df['profit'], color ="skyblue")
plt.title("profit by customer_rating")
plt.xlabel('customer_rating')
plt.ylabel('profit')
plt.show()

# %%
plt.scatter(df['discount_percent'],df['customer_rating'], color ="skyblue")
plt.title("customer_rating by discount_percent")
plt.xlabel('discount_percent')
plt.ylabel('customer_rating')
plt.show()

# %% [markdown]
# - **Same discount percent for all rating of customers**
# - **The discount percent is fixed**

# %%
plt.scatter(df['customer_rating'], df['quantity_sold'])
plt.xlabel("customer_rating")
plt.ylabel("quantity_sold")
plt.title("customer_rating vs quantity_sold")
plt.show()

# %% [markdown]
# - **No effect of customer rating on quantity sold**
# - **Quantity sold is similar for all ratings**

# %%
plt.scatter(df['cumulative_sales_outlet'], df['total_bill'])
plt.xlabel("cumulative_sales_outlet")
plt.ylabel("total_bill")
plt.title("cumulative_sales_outlet vs total_bill")
plt.show()

# %%
x = df['item_category']

plt.bar(x, df['total_bill'], label='total_bill', color='skyblue')
plt.bar(x, df['cost_price'], label='cost_price', color='orange')

plt.xlabel('item_category')
plt.ylabel('Amount')
plt.title('Stacked total_bill and cost_price by item_category')
plt.legend()
plt.show()

# %% [markdown]
# - **All categories are almost similar**
# - **Total bill around 1200 and cost price around 900**

# %%
plt.boxplot(df['quantity_sold'])
plt.title('quantity_sold Distribution Box Plot')
plt.ylabel('quantity_sold')
plt.show()

# %% [markdown]
# - **The data is distributed between 1.0 to 4.0 range.**
# - **The 50% quantity sold is between 2.0 to 3.0 range.**
# - **The median quantity sold is on 3.0**
# - **There are no outliers found in this column**

# %%
IQR = 3.000000 - 2.000000	
print(IQR)
lower_limit = 2.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 3.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 1.0
# 0.5
# 4.5

# %%
plt.boxplot(df['price_per_unit'])
plt.title('price_per_unit Distribution Box Plot')
plt.ylabel('price_per_unit')
plt.show()

# %% [markdown]
# - **The data is distributed between 100 to 300 range.**
# - **The 50% price per unit is between 150 to 250 range.**
# - **The median price per unit is near 200**
# - **There are no outliers found in this column**

# %%
IQR = 249.000000 - 150.000000	
print(IQR)
lower_limit = 150.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 249.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 99.0
# 1.5
# 397.5

# %%
plt.boxplot(df['total_bill'])
plt.title('total_bill Distribution Box Plot')
plt.ylabel('total_bill')
plt.show()

# %% [markdown]
# - **The data is distributed between 100 to 1200 range.**
# - **The 50% total bill between 300 to 700 range.**
# - **The median total bill is near 500**
# - **There are no outliers found in this column**

# %%
IQR = 696.750000 - 267.750000	
print(IQR)
lower_limit = 267.750000 - 1.5 * IQR
print(lower_limit)
upper_limit = 696.750000 + 1.5 * IQR
print(upper_limit)
# Out:
# 429.0
# -375.75
# 1340.25

# %%
plt.boxplot(df['cost_price'])
plt.title('cost_price Distribution Box Plot')
plt.ylabel('cost_price')
plt.show()

# %% [markdown]
# - **The data is distributed between 100 to 500 range**
# - **The 50% of cost price is between 200 to 450 range**
# - **The median cost price is near 300**
# - **There are extreme high level outliers in this column**

# %%
IQR = 478.690000 - 183.082500	
print(IQR)
lower_limit = 183.082500 - 1.5 * IQR
print(lower_limit)
upper_limit = 478.690000 + 1.5 * IQR
print(upper_limit)
# Out:
# 295.60749999999996
# -260.3287499999999
# 922.1012499999999

# %%
plt.boxplot(df['profit'])
plt.title('profit Distribution Box Plot')
plt.ylabel('profit')
plt.show()

# %% [markdown]
# - **The data is distributed between 10 to 380 range**
# - **The 50% of profit is between 90 to 200 range**
# - **The median profit is near 130**
# - **There are extreme high level outliers in this column**

# %%
IQR = 203.172500 - 79.637500	
print(IQR)
lower_limit = 79.637500 - 1.5 * IQR
print(lower_limit)
upper_limit = 203.172500 + 1.5 * IQR
print(upper_limit)
# Out:
# 123.53500000000001
# -105.665
# 388.475

# %%
plt.boxplot(df['temperature_c'])
plt.title('temperature_c Distribution Box Plot')
plt.ylabel('temperature_c')
plt.show()

# %% [markdown]
# - **The data is distributed between 24 to 40 range.**
# - **The 50% temperature is  between 27 to 32 range.**
# - **The median temperature is near 29 celsius**
# - **There are no outliers found in this column**

# %%
IQR = 32.300000 - 26.775000	
print(IQR)
lower_limit = 26.775000 - 1.5 * IQR
print(lower_limit)
upper_limit = 32.300000 + 1.5 * IQR
print(upper_limit)
# Out:
# 5.524999999999999
# 18.4875
# 40.58749999999999

# %%
plt.boxplot(df['customer_rating'])
plt.title('customer_rating Distribution Box Plot')
plt.ylabel('customer_rating')
plt.show()

# %% [markdown]
# - **The data is distributed between 3.00 to 5.00 range.**
# - **The 50% customer rating is between 3.50 to 4.50 range.**
# - **The median customer rating is near 4.00**
# - **There are no outliers found in this column**

# %%
IQR = 4.500000 - 3.500000	
print(IQR)
lower_limit = 3.500000 - 1.5 * IQR
print(lower_limit)
upper_limit = 4.500000 + 1.5 * IQR
print(upper_limit)
# Out:
# 1.0
# 2.0
# 6.0

# %%
plt.boxplot(df['discount_percent'])
plt.title('discount_percent Distribution Box Plot')
plt.ylabel('discount_percent')
plt.show()

# %% [markdown]
# - **The data is distributed between 0 to 15 range.**
# - **The 50% discount percent is between 5 to 15 range.**
# - **The median discount percent is near 10**
# - **There are no outliers found in this column**

# %%
IQR = 15.000000 - 5.000000	
print(IQR)
lower_limit = 5.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 15.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 10.0
# -10.0
# 30.0

# %%
plt.boxplot(df['final_amount'])
plt.title('final_amount Distribution Box Plot')
plt.ylabel('final_amount')
plt.show()

# %% [markdown]
# - **The data is distributed between 100 to 1200 range.**
# - **The 50% final amount is between 220 to 610 range.**
# - **The median final amount is near 400**
# - **There are no outliers found in this column**

# %%
IQR = 636.300000 - 246.575000	
print(IQR)
lower_limit = 246.575000 - 1.5 * IQR
print(lower_limit)
upper_limit = 636.300000 + 1.5 * IQR
print(upper_limit)
# Out:
# 389.72499999999997
# -338.0125
# 1220.8874999999998

# %%
plt.boxplot(df['cumulative_sales_outlet'])
plt.title('cumulative_sales_outlet Distribution Box Plot')
plt.ylabel('cumulative_sales_outlet')
plt.show()

# %% [markdown]
# - **The data is distributed between 0 to 190000 range.**
# - **The 50% cumulative sales between 50000 to 140000 range.**
# - **The median cumulative sales is near 85000**
# - **There are no outliers found in this column**

# %%
IQR = 138889.637500 - 46386.687500	
print(IQR)
lower_limit = 46386.687500 - 1.5 * IQR
print(lower_limit)
upper_limit = 138889.637500 + 1.5 * IQR
print(upper_limit)
# Out:
# 92502.95000000001
# -92367.73750000002
# 277644.0625
